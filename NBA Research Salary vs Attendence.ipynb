# %%
import pandas as pd
from pathlib import Path

# %%
Path = 'NBA Team Annual Attendance.csv'
Attdf = pd.read_csv(Path)
Attdf.head()
# Out:
#    Starting Year  Rank       Team  Home: Total Games Home: Total Attendance  \
# 0           2015     1      Bulls                 41                894,659
# 1           2015     2  Cavaliers                 41                843,042
# 2           2015     3  Mavericks                 41                825,901
# 3           2015     4    Raptors                 41                812,863
# 4           2015     5  NY Knicks                 41                812,292
#
#   Home: Avg Attendance Home: % Capactiy  Away: Total Games  \
# 0               21,820            104.3                 41
# 1               20,562              100                 41
# 2               20,143            104.9                 41
# 3               19,825            100.1                 41
# 4               19,812              100                 41
#
#   Away: Total Attendance Away: Avg Attendance  Away: % Capactiy
# 0                 18,156                 94.5                82
# ...

# %%
Attdf.columns
# Out:
# Index(['Starting Year', 'Rank', 'Team', 'Home: Total Games',
#        'Home: Total Attendance', 'Home: Avg Attendance', 'Home: % Capactiy',
#        'Away: Total Games', 'Away: Total Attendance', 'Away: Avg Attendance',
#        'Away: % Capactiy'],
#       dtype='object')

# %%
Attdf.dtypes
# Out:
# Starting Year              int64
# Rank                       int64
# Team                      object
# Home: Total Games          int64
# Home: Total Attendance    object
# Home: Avg Attendance      object
# Home: % Capactiy          object
# Away: Total Games          int64
# Away: Total Attendance    object
# Away: Avg Attendance      object
# Away: % Capactiy           int64
# dtype: object

# %%
Attdf[['Starting Year', 'Rank', 'Team', 'Home: Total Games','Away: Total Games',
       'Home: Total Attendance', 'Away: Total Attendance','Home: % Capactiy',
        'Away: Total Attendance', 'Away: Avg Attendance',
       'Away: % Capactiy']]
# Out:
#      Starting Year  Rank       Team  Home: Total Games  Away: Total Games  \
# 0             2015     1      Bulls                 41                 41
# 1             2015     2  Cavaliers                 41                 41
# 2             2015     3  Mavericks                 41                 41
# 3             2015     4    Raptors                 41                 41
# 4             2015     5  NY Knicks                 41                 41
# ..             ...   ...        ...                ...                ...
# 471           2000    25   Warriors                 41                 41
# 472           2000    26       Nets                 41                 41
# 473           2000    27  Grizzlies                 41                 41
# 474           2000    28      Hawks                 41                 41
# 475           2000    29    Rockets                 41                 41
#
#     Home: Total Attendance Away: Total Attendance Home: % Capactiy  \
# ...

# %%
Path2 = 'NBASalaries1990to2016.csv'
salarydf = pd.read_csv(Path2)
salarydf.head()
# Out:
#             Team  Season_Start  Season_End  Rk             Player   Salary
# 0  Atlanta Hawks          1990        1991   1       Moses Malone  2406000
# 1  Atlanta Hawks          1990        1991   2  Dominique Wilkins  2065000
# 2  Atlanta Hawks          1990        1991   3         Jon Koncak  1550000
# 3  Atlanta Hawks          1990        1991   4         Doc Rivers   895000
# 4  Atlanta Hawks          1990        1991   5    Rumeal Robinson   800000
