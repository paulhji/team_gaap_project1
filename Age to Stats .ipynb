# %%
# Import Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../Desktop/nba_peak_age.csv")

# %%
data
# Out:
#       Unnamed: 0  Index               Player  Age  Seasons   Tm   Lg Pos  \
# 0              0      1  Kareem Abdul-Jabbar   22  1969-70  MIL  NBA   C
# 1              1      1  Kareem Abdul-Jabbar   23  1970-71  MIL  NBA   C
# 2              2      1  Kareem Abdul-Jabbar   24  1971-72  MIL  NBA   C
# 3              3      1  Kareem Abdul-Jabbar   25  1972-73  MIL  NBA   C
# 4              4      1  Kareem Abdul-Jabbar   26  1973-74  MIL  NBA   C
# ...          ...    ...                  ...  ...      ...  ...  ...  ..
# 1962        1962    152       George Yardley   29  1957-58  DET  NBA  SF
# 1963        1963    152       George Yardley   30  1958-59  TOT  NBA  SF
# 1964        1964    152       George Yardley   30  1958-59  DET  NBA  SF
# 1965        1965    152       George Yardley   30  1958-59  SYR  NBA  SF
# 1966        1966    152       George Yardley   31  1959-60  SYR  NBA  SF
#
#          G  GS  ...      nFG%     neFG%      nFT%      nTRB      nAST  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Index', 'Player', 'Age', 'Seasons', 'Tm', 'Lg', 'Pos',
#        'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'full_count', 'Performance', 'max',
#        'Peak_Age', 'Peak_Season', 'BirthYear', 'Decade', 'Debut_Age',
#        'Years_To_Prime', 'nFG%', 'neFG%', 'nFT%', 'nTRB', 'nAST', 'nSTL',
#        'nBLK', 'nTOV', 'nPF', 'nPTS'],
#       dtype='object')

# %%
clean_data=data[["Player","Age","Peak_Age","PTS", ]]
clean_data
# Out:
#                    Player  Age  Peak_Age   PTS
# 0     Kareem Abdul-Jabbar   22        28  28.8
# 1     Kareem Abdul-Jabbar   23        28  31.7
# 2     Kareem Abdul-Jabbar   24        28  34.8
# 3     Kareem Abdul-Jabbar   25        28  30.2
# 4     Kareem Abdul-Jabbar   26        28  27.0
# ...                   ...  ...       ...   ...
# 1962       George Yardley   29        29  27.8
# 1963       George Yardley   30        29  19.8
# 1964       George Yardley   30        29  20.8
# 1965       George Yardley   30        29  16.7
# 1966       George Yardley   31        29  20.2
#
# [1967 rows x 4 columns]

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
points = clean_data["PTS"] 
x_axis = clean_data["Age"]
plt.bar(x_axis, points, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 1967 artists>
